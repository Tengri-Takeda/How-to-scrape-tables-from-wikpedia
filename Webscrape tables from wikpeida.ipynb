# %%
import pandas as pd

# %%
# the wikpedia source you want to scrape
dfs = pd.read_html('https://en.wikipedia.org/wiki/Demography_of_the_United_Kingdom')

# %%
#find how many tables there are
len(dfs)
# Out:
# 46

# %%
dfs[1]
# Out:
#    Demographics of the United Kingdom  \
# 0          Population pyramid in 2020
# 1                          Population
# 2                             Density
# 3                         Growth rate
# 4                          Birth rate
# 5                          Death rate
# 6                     Life expectancy
# 7                              • male
# 8                            • female
# 9                      Fertility rate
# 10              Infant mortality rate
# 11                 Net migration rate
# 12                      Age structure
# 13                         0–14 years
# 14                        15–64 years
# 15                        65 and over
# 16                          Sex ratio
# 17                           At birth
# 18                           Under 15
# 19                        65 and over
# 20                        Nationality
# 21                        Nationality
# 22                       Major ethnic
# ...

# %%
# save as csv file
dfs[1].to_csv('sample_census.csv')
